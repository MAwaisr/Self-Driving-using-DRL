# %% [markdown]
# 1) Sensor Fusion (No Camera) synchronous

# %%
import glob
import os
import sys
import carla
import random
import time
import numpy as np
import cv2

SHOW_PREVIEW = False
IM_WIDTH = 640
IM_HEIGHT = 480
SECONDS_PER_EPISODE = 10

actor_list = []
collision_hist = []

# Function to process IMU data
def process_imu(imu_data):
    acceleration = imu_data.accelerometer
    gyroscope = imu_data.gyroscope
    compass = imu_data.compass
    print("Acceleration:", acceleration)
    print("Gyroscope:", gyroscope)
    print("Compass:", compass)

# Function to process LiDAR data
def lidar_callback(data):
    lidar_data = np.frombuffer(data.raw_data, dtype=np.dtype('f4'))
    print("LiDAR Data:", lidar_data)
    with open('lidar_data.txt', 'w') as file:
        file.write(str(lidar_data))

# Function to handle collisions
def collision_data(event):
    collision_hist.append(event)
    print("Collision Detected!")

try:
    client = carla.Client('localhost', 2000)
    client.set_timeout(20)
    world = client.get_world()
    blueprint_library = world.get_blueprint_library()
    bp = blueprint_library.filter('model3')[0]
    spawn_point = random.choice(world.get_map().get_spawn_points())
    fixed_spawn_point = carla.Transform(
    location=carla.Location(x=100, y=100, z=0.1),
    rotation=carla.Rotation(pitch=0, yaw=-90, roll=0)  # Adjust the rotation as needed
)  
    vehicle = world.spawn_actor(bp, fixed_spawn_point)
    #vehicle = world.spawn_actor(bp, spawn_point)
    vehicle.apply_control(carla.VehicleControl(throttle=0.4, steer=0.01))
    actor_list.append(vehicle)

    # Adding IMU sensor
    imu = blueprint_library.find('sensor.other.imu')
    spawn_point = carla.Transform(carla.Location(x=2.9, z=0.7))
    imu_sensor = world.spawn_actor(imu, spawn_point, attach_to=vehicle)
    actor_list.append(imu_sensor)
    imu_sensor.listen(lambda data: process_imu(data))

    # Adding LiDAR sensor
    lidar = blueprint_library.find('sensor.lidar.ray_cast')
    spawn_point = carla.Transform(carla.Location(x=5.6, z=0.7))
    lidar_sensor = world.spawn_actor(lidar, spawn_point, attach_to=vehicle)
    actor_list.append(lidar_sensor)
    lidar_sensor.listen(lidar_callback)

    # Adding Collision sensor
    col_sensor = blueprint_library.find('sensor.other.collision')
    spawn_point = carla.Transform(carla.Location(x=2.9, z=0.7))
    collision_sensor = world.spawn_actor(col_sensor, spawn_point, attach_to=vehicle)
    actor_list.append(collision_sensor)
    collision_sensor.listen(collision_data)

    # Enable synchronous mode with a fixed time step
    settings = world.get_settings()
    settings.synchronous_mode = True
    settings.fixed_delta_seconds = 0.1
    world.apply_settings(settings)

    # Run the simulation for a fixed duration (in synchronous mode)
    for _ in range(int(SECONDS_PER_EPISODE * 40)):
        world.tick()
        # Sensor fusion and decision-making logic can be implemented here
        # You can access data from collision_hist, IMU, and LiDAR in this section
        # Implement your desired logic for making decisions based on the sensor data

finally:
    print('Destroying actors')
    for actor in actor_list:
        actor.destroy()
    print('Done.')

    # Disable synchronous mode before exiting
    settings.synchronous_mode = False
    world.apply_settings(settings)
# Out:
# Acceleration: Vector3D(x=-0.000000, y=0.000000, z=9.810000)
# Gyroscope: Vector3D(x=-0.000001, y=-0.000000, z=-0.000000)
# Compass: 0.0
# Acceleration: Vector3D(x=9709.997070, y=-9999.998047, z=-61.871181)
# Gyroscope: Vector3D(x=-0.000001, y=-0.000000, z=-0.000000)
# Compass: 0.0
# Acceleration: Vector3D(x=0.000000, y=0.000000, z=10.137545)
# Gyroscope: Vector3D(x=-0.000001, y=-0.000000, z=-0.000000)
# Compass: 0.0
# LiDAR Data: [ 4.5743165 -5.9521484  1.3236543 ...  0.1309375 -0.7032986  0.9943894]
# LiDAR Data: [ 4.5737987  -5.951445    1.1498687  ...  0.08726563 -0.70234144
#   0.99439704]
# Acceleration: Vector3D(x=0.000000, y=0.000000, z=9.946362)
# Gyroscope: Vector3D(x=0.000001, y=0.000000, z=0.000000)
# Compass: 0.0
# Acceleration: Vector3D(x=0.000000, y=0.000000, z=9.866426)
# Gyroscope: Vector3D(x=-0.000001, y=0.000000, z=0.000000)
# Compass: 0.0
# LiDAR Data: [ 4.574326   -5.952129    1.3236531  ...  0.17399414 -0.7019485
#   0.99440014]
# Acceleration: Vector3D(x=0.000000, y=0.000000, z=9.838673)
# Gyroscope: Vector3D(x=0.000000, y=0.000000, z=0.000000)
# Compass: 0.0
# LiDAR Data: [ 4.574326   -5.952129    1.323653   ...  0.04363281 -0.7018423
#   0.99440104]
# Acceleration: Vector3D(x=0.000000, y=0.000000, z=9.814273)
# Gyroscope: Vector3D(x=-0.000000, y=0.000000, z=0.000000)
# Compass: 0.0
# LiDAR Data: [ 4.574326   -5.952129    1.323653   ...  0.13066407 -0.7017788
#   0.9944015 ]
# Acceleration: Vector3D(x=0.000000, y=0.000000, z=9.811651)
# Gyroscope: Vector3D(x=0.000000, y=0.000000, z=0.000000)
# Compass: 0.0
# LiDAR Data: [ 4.574326   -5.952129    1.3236531  ...  0.08719727 -0.70173186
#   0.9944019 ]
# Acceleration: Vector3D(x=2.923007, y=0.047283, z=9.936418)
# Gyroscope: Vector3D(x=0.000274, y=-0.010530, z=0.003703)
# Compass: 0.0
# LiDAR Data: [ 4.5602927  -5.933906    1.1464764  ...  0.04374023 -0.7036913
#   0.99438626]
# Acceleration: Vector3D(x=11.140871, y=0.148090, z=9.858902)
# Gyroscope: Vector3D(x=0.000029, y=-0.002832, z=0.004790)
# Compass: 0.0005980199784971774
# LiDAR Data: [-5.3414745  -0.19186524  0.6960205  ...  0.0878125  -0.70662826
#   0.99436295]
# Acceleration: Vector3D(x=5.569428, y=0.210196, z=9.612973)
# Gyroscope: Vector3D(x=0.000069, y=0.001914, z=0.023593)
# Compass: 0.0015822122804820538
# LiDAR Data: [ 4.234375   -5.939502    1.1174518  ...  0.04394531 -0.7065547
#   0.9943635 ]
# Acceleration: Vector3D(x=2.986943, y=-0.013929, z=9.751471)
# Gyroscope: Vector3D(x=0.000071, y=0.002332, z=0.023938)
# Compass: 0.002441406948491931
# LiDAR Data: [-5.3119335   0.          0.69172436 ...  0.08768555 -0.70561105
#   0.99437106]
# Acceleration: Vector3D(x=2.335272, y=0.056679, z=9.817000)
# Gyroscope: Vector3D(x=0.000059, y=0.001709, z=0.023955)
# Compass: 0.003435364691540599
# LiDAR Data: [-5.3119431e+00 -9.7656248e-06  6.9172609e-01 ...  4.3828122e-02
#  -7.0479697e-01  9.9437743e-01]
# Acceleration: Vector3D(x=2.100235, y=0.053434, z=9.825047)
# Gyroscope: Vector3D(x=0.000056, y=0.001118, z=0.023887)
# Compass: 0.00444845762103796
# LiDAR Data: [-5.3119531e+00 -9.7656248e-06  6.9172609e-01 ...  8.7519526e-02
#  -7.0424664e-01  9.9438184e-01]
# Acceleration: Vector3D(x=1.981976, y=0.059905, z=9.821515)
# Gyroscope: Vector3D(x=0.000054, y=0.000710, z=0.023723)
# Compass: 0.005556553602218628
# LiDAR Data: [-5.3414645  -0.19186524  0.6960193  ...  0.08749023 -0.70389175
#   0.9943847 ]
# Acceleration: Vector3D(x=1.905870, y=0.058108, z=9.817269)
# Gyroscope: Vector3D(x=0.000054, y=0.000458, z=0.023458)
# Compass: 0.006739355623722076
# LiDAR Data: [ 2.8299217  -6.013906    1.0181758  ...  0.08745117 -0.70366573
#   0.99438643]
# Acceleration: Vector3D(x=1.847519, y=0.064363, z=9.814026)
# Gyroscope: Vector3D(x=0.000049, y=0.000308, z=0.023086)
# Compass: 0.007978602312505245
# LiDAR Data: [ 2.5673926  -6.0067086   1.000722   ...  0.08742187 -0.7035166
#   0.9943877 ]
# Acceleration: Vector3D(x=1.794266, y=0.066228, z=9.812253)
# Gyroscope: Vector3D(x=0.000049, y=0.000222, z=0.022597)
# Compass: 0.00929021742194891
# LiDAR Data: [-5.341484   -0.19186524  0.6960213  ...  0.0437207  -0.70341253
#   0.99438846]
# Acceleration: Vector3D(x=1.743599, y=0.069358, z=9.810897)
# Gyroscope: Vector3D(x=0.000048, y=0.000172, z=0.021962)
# Compass: 0.010647492483258247
# LiDAR Data: [ 1.8405077  -6.0307617   1.1118084  ...  0.04374023 -0.70333654
#   0.9943891 ]
# Acceleration: Vector3D(x=1.697983, y=0.072470, z=9.810198)
# Gyroscope: Vector3D(x=0.000046, y=0.000143, z=0.021149)
# Compass: 0.012064672075212002
# LiDAR Data: [ 1.3835645  -6.0618067   1.0963452  ...  0.04371094 -0.7032744
#   0.9943896 ]
# Acceleration: Vector3D(x=1.646204, y=0.079448, z=9.809928)
# Gyroscope: Vector3D(x=0.000044, y=0.000134, z=0.020409)
# Compass: 0.013540557585656643
# LiDAR Data: [-5.3119431e+00 -9.7656248e-06  6.9172460e-01 ...  4.3720704e-02
#  -7.0322078e-01  9.9439001e-01]
# Acceleration: Vector3D(x=1.590646, y=0.082158, z=9.809539)
# Gyroscope: Vector3D(x=0.000042, y=0.000131, z=0.019820)
# Compass: 0.015081631951034069
# LiDAR Data: [-5.311943    0.          0.6917252  ...  0.0437207  -0.70316917
#   0.9943904 ]
# Acceleration: Vector3D(x=1.536388, y=0.086817, z=9.809520)
# Gyroscope: Vector3D(x=0.000039, y=0.000125, z=0.019143)
# Compass: 0.016673406586050987
# LiDAR Data: [-5.3119431e+00  9.7656248e-06  6.9172764e-01 ...  4.3730468e-02
#  -7.0311862e-01  9.9439090e-01]
# Acceleration: Vector3D(x=1.488306, y=0.085831, z=9.809637)
# Gyroscope: Vector3D(x=0.000037, y=0.000117, z=0.018360)
# Compass: 0.018315685912966728
# LiDAR Data: [-5.341484   -0.19186524  0.69601965 ...  0.04374023 -0.70307064
#   0.9943912 ]
# Acceleration: Vector3D(x=1.435425, y=0.094409, z=9.809744)
# Gyroscope: Vector3D(x=0.000037, y=0.000114, z=0.017720)
# Compass: 0.02000795304775238
# LiDAR Data: [-4.974697   -0.53791994  0.53730565 ...  0.04370117 -0.70302594
#   0.99439156]
# Acceleration: Vector3D(x=1.389944, y=0.096679, z=9.809490)
# Gyroscope: Vector3D(x=0.000034, y=0.000111, z=0.017713)
# Compass: 0.0217522494494915
# LiDAR Data: [-1.2849804  -6.1355762   0.9603192  ...  0.08736328 -0.702984
#   0.994392  ]
# Acceleration: Vector3D(x=1.338861, y=0.099181, z=9.809731)
# Gyroscope: Vector3D(x=0.000035, y=0.000106, z=0.018109)
# Compass: 0.023544613271951675
# LiDAR Data: [-5.311943    0.          0.69172585 ...  0.0436914  -0.70293736
#   0.9943923 ]
# Acceleration: Vector3D(x=1.296613, y=0.104084, z=9.816798)
# Gyroscope: Vector3D(x=0.000049, y=0.000114, z=0.018534)
# Compass: 0.025377217680215836
# LiDAR Data: [-2.2361913  -6.124863    1.1497042  ...  0.13089843 -0.7029743
#   0.9943919 ]
# Acceleration: Vector3D(x=1.052431, y=0.103299, z=9.815438)
# Gyroscope: Vector3D(x=-0.000221, y=0.002456, z=0.017812)
# Compass: 0.02725069969892502
# LiDAR Data: [-5.341484   -0.191875    0.69602036 ...  0.2602539  -0.7030013
#   0.9943918 ]
# Acceleration: Vector3D(x=-0.260218, y=0.080142, z=9.767741)
# Gyroscope: Vector3D(x=-0.000169, y=0.001609, z=0.017781)
# Compass: 0.029120363295078278
# LiDAR Data: [-3.313369   -6.157246    1.070868   ...  0.0436914  -0.7025035
#   0.99439573]
# Acceleration: Vector3D(x=0.289294, y=0.096143, z=9.833494)
# Gyroscope: Vector3D(x=-0.000168, y=0.000912, z=0.017998)
# Compass: 0.030994601547718048
# LiDAR Data: [-5.3415036  -0.19188476  0.69602066 ...  0.04367187 -0.70239645
#   0.9943965 ]
# Acceleration: Vector3D(x=-0.108095, y=0.090475, z=9.793264)
# Gyroscope: Vector3D(x=-0.000134, y=0.001170, z=0.018183)
# Compass: 0.0328708253800869
# LiDAR Data: [-5.3119531e+00 -2.9296874e-05  6.9172865e-01 ...  8.7207027e-02
#  -7.0200455e-01  9.9439973e-01]
# Acceleration: Vector3D(x=-0.345268, y=0.091424, z=9.824240)
# Gyroscope: Vector3D(x=-0.000111, y=0.000454, z=0.018180)
# Compass: 0.03474700078368187
# LiDAR Data: [-4.8261814e+00  9.7656248e-06  5.1824361e-01 ...  1.3068359e-01
#  -7.0184362e-01  9.9440104e-01]
# Acceleration: Vector3D(x=0.051619, y=0.093818, z=9.823358)
# Gyroscope: Vector3D(x=-0.000110, y=0.000136, z=0.018245)
# Compass: 0.03662639483809471
# LiDAR Data: [-5.3119335   0.          0.69172543 ...  0.08720703 -0.70188445
#   0.9944007 ]
# Acceleration: Vector3D(x=0.302527, y=0.100347, z=9.814588)
# Gyroscope: Vector3D(x=-0.000110, y=0.000068, z=0.018371)
# Compass: 0.038513194769620895
# LiDAR Data: [-5.3414645  -0.191875    0.6960211  ...  0.04364258 -0.7019946
#   0.9943998 ]
# Acceleration: Vector3D(x=0.441944, y=0.101670, z=9.810258)
# Gyroscope: Vector3D(x=-0.000109, y=0.000103, z=0.018535)
# Compass: 0.040415216237306595
# LiDAR Data: [-5.3414745  -0.19186524  0.69602036 ...  0.04366211 -0.7021099
#   0.9943989 ]
# Acceleration: Vector3D(x=0.523835, y=0.104264, z=9.808579)
# Gyroscope: Vector3D(x=-0.000108, y=0.000166, z=0.018719)
# Compass: 0.04233323037624359
# LiDAR Data: [-5.341494   -0.19185546  0.69602054 ...  0.13075195 -0.70220935
#   0.99439806]
# Acceleration: Vector3D(x=0.561799, y=0.104728, z=9.808318)
# Gyroscope: Vector3D(x=-0.000105, y=0.000226, z=0.018912)
# Compass: 0.04427056014537811
# LiDAR Data: [-5.341484   -0.19186524  0.6960209  ...  0.04367187 -0.7022697
#   0.99439764]
# Acceleration: Vector3D(x=0.581157, y=0.109648, z=9.808500)
# Gyroscope: Vector3D(x=-0.000104, y=0.000274, z=0.019110)
# Compass: 0.046227358281612396
# LiDAR Data: [-5.341484   -0.19186524  0.6960215  ...  0.08727539 -0.70231706
#   0.9943972 ]
# Acceleration: Vector3D(x=0.587205, y=0.111362, z=9.808813)
# Gyroscope: Vector3D(x=-0.000104, y=0.000308, z=0.019309)
# Compass: 0.04820497706532478
# LiDAR Data: [-5.311953    0.          0.6917265  ...  0.17410156 -0.70235085
#   0.99439704]
# Acceleration: Vector3D(x=0.587491, y=0.110832, z=9.809172)
# Gyroscope: Vector3D(x=-0.000101, y=0.000331, z=0.019507)
# Compass: 0.05019977688789368
# LiDAR Data: [-5.3119483   0.          0.6917272  ...  0.08730469 -0.70235777
#   0.9943969 ]
# Acceleration: Vector3D(x=0.584244, y=0.114855, z=9.809420)
# Gyroscope: Vector3D(x=-0.000101, y=0.000345, z=0.019701)
# Compass: 0.05221664905548096
# LiDAR Data: [-5.34147     0.1918457   0.6960215  ...  0.04366211 -0.70236105
#   0.99439687]
# Acceleration: Vector3D(x=0.577294, y=0.119708, z=9.809600)
# Gyroscope: Vector3D(x=-0.000102, y=0.000354, z=0.019895)
# Compass: 0.0542498417198658
# LiDAR Data: [-5.3119678e+00  1.9531250e-05  6.9172668e-01 ...  1.3078125e-01
#  -7.0237023e-01  9.9439681e-01]
# Acceleration: Vector3D(x=0.570739, y=0.120170, z=9.809719)
# Gyroscope: Vector3D(x=-0.000101, y=0.000359, z=0.020087)
# Compass: 0.0563039556145668
# LiDAR Data: [-4.826172    0.          0.5182432  ...  0.0436914  -0.7023607
#   0.99439687]
# Acceleration: Vector3D(x=0.561616, y=0.119552, z=9.809720)
# Gyroscope: Vector3D(x=-0.000100, y=0.000361, z=0.020284)
# Compass: 0.0583757720887661
# LiDAR Data: [-5.3119431e+00 -9.7656248e-06  6.9172466e-01 ...  4.3652344e-02
#  -7.0235616e-01  9.9439687e-01]
# Acceleration: Vector3D(x=0.555101, y=0.120683, z=9.809912)
# Gyroscope: Vector3D(x=-0.000097, y=0.000362, z=0.020478)
# Compass: 0.060467422008514404
# LiDAR Data: [-5.3119483e+00  9.7656248e-06  6.9172573e-01 ...  8.7265626e-02
#  -7.0235497e-01  9.9439687e-01]
# Acceleration: Vector3D(x=0.545202, y=0.127679, z=9.809845)
# Gyroscope: Vector3D(x=-0.000099, y=0.000362, z=0.020669)
# Compass: 0.06257788091897964
# LiDAR Data: [-5.3119578e+00  2.9296874e-05  6.9172567e-01 ...  8.7294921e-02
#  -7.0234883e-01  9.9439687e-01]
# Acceleration: Vector3D(x=0.537428, y=0.128309, z=9.809891)
# Gyroscope: Vector3D(x=-0.000097, y=0.000362, z=0.020858)
# Compass: 0.06470809131860733
# LiDAR Data: [-5.3414745   0.19186524  0.6960205  ...  0.08725586 -0.7023423
#   0.99439704]
# Acceleration: Vector3D(x=0.529078, y=0.129627, z=9.809896)
# Gyroscope: Vector3D(x=-0.000098, y=0.000361, z=0.021043)
# Compass: 0.0668552815914154
# LiDAR Data: [-5.3414893   0.19185546  0.69602215 ...  0.04367187 -0.7023309
#   0.9943971 ]
# Acceleration: Vector3D(x=0.522159, y=0.133381, z=9.809961)
# Gyroscope: Vector3D(x=-0.000099, y=0.000359, z=0.021226)
# Compass: 0.06902220100164413
# LiDAR Data: [-5.341494   -0.191875    0.69602126 ...  0.17410156 -0.7023374
#   0.99439704]
# Acceleration: Vector3D(x=0.513033, y=0.132302, z=9.809895)
# Gyroscope: Vector3D(x=-0.000096, y=0.000358, z=0.021403)
# Compass: 0.07120621204376221
# LiDAR Data: [-5.3119626e+00  9.7656248e-06  6.9172651e-01 ...  8.7275386e-02
#  -7.0232153e-01  9.9439710e-01]
# Acceleration: Vector3D(x=0.504944, y=0.136819, z=9.809945)
# Gyroscope: Vector3D(x=-0.000097, y=0.000356, z=0.021580)
# Compass: 0.07340744137763977
# LiDAR Data: [-5.341494   -0.19186524  0.69602054 ...  0.13076171 -0.70231885
#   0.99439716]
# Acceleration: Vector3D(x=0.498373, y=0.136230, z=9.809937)
# Gyroscope: Vector3D(x=-0.000097, y=0.000356, z=0.021753)
# Compass: 0.07562597095966339
# LiDAR Data: [-5.3119431e+00  9.7656248e-06  6.9172657e-01 ...  4.3662108e-02
#  -7.0230329e-01  9.9439734e-01]
# Acceleration: Vector3D(x=0.488647, y=0.143438, z=9.809898)
# Gyroscope: Vector3D(x=-0.000095, y=0.000354, z=0.021923)
# Compass: 0.07786186784505844
# LiDAR Data: [-5.3414793   0.191875    0.6960209  ...  0.04367187 -0.7022961
#   0.99439734]
# Acceleration: Vector3D(x=0.481374, y=0.141710, z=9.809999)
# Gyroscope: Vector3D(x=-0.000097, y=0.000353, z=0.022090)
# Compass: 0.08011368662118912
# LiDAR Data: [-5.3119383e+00  9.7656248e-06  6.9172537e-01 ...  4.3681640e-02
#  -7.0228958e-01  9.9439746e-01]
# Acceleration: Vector3D(x=0.473836, y=0.144418, z=9.809916)
# Gyroscope: Vector3D(x=-0.000095, y=0.000351, z=0.022254)
# Compass: 0.08238159120082855
# LiDAR Data: [-5.34147    -0.191875    0.6960195  ...  0.04365234 -0.7022829
#   0.9943975 ]
# Acceleration: Vector3D(x=0.466156, y=0.145286, z=9.809941)
# Gyroscope: Vector3D(x=-0.000093, y=0.000350, z=0.022415)
# Compass: 0.08466711640357971
# LiDAR Data: [-5.3119383   0.          0.6917257  ...  0.04367187 -0.70227623
#   0.9943976 ]
# Acceleration: Vector3D(x=0.459324, y=0.148613, z=9.809933)
# Gyroscope: Vector3D(x=-0.000093, y=0.000349, z=0.022574)
# Compass: 0.08696752041578293
# LiDAR Data: [-5.3119483e+00  1.9531250e-05  6.9172657e-01 ...  8.7265626e-02
#  -7.0227402e-01  9.9439758e-01]
# Acceleration: Vector3D(x=0.451156, y=0.150838, z=9.809935)
# Gyroscope: Vector3D(x=-0.000093, y=0.000347, z=0.022729)
# Compass: 0.0892823338508606
# LiDAR Data: [-5.3119483e+00 -1.9531250e-05  6.9172704e-01 ...  4.3652344e-02
#  -7.0226270e-01  9.9439764e-01]
# Acceleration: Vector3D(x=0.443118, y=0.154333, z=9.809954)
# Gyroscope: Vector3D(x=-0.000094, y=0.000346, z=0.022883)
# Compass: 0.09161373972892761
# LiDAR Data: [-5.3119287e+00  9.7656248e-06  6.9172758e-01 ...  4.3671872e-02
#  -7.0225602e-01  9.9439776e-01]
# Acceleration: Vector3D(x=0.436887, y=0.150164, z=9.809966)
# Gyroscope: Vector3D(x=-0.000093, y=0.000345, z=0.023033)
# Compass: 0.09396050870418549
# LiDAR Data: [-5.3414793  -0.1918457   0.69602025 ...  0.04368164 -0.7022499
#   0.99439776]
# Acceleration: Vector3D(x=0.429473, y=0.159945, z=9.809893)
# Gyroscope: Vector3D(x=-0.000092, y=0.000343, z=0.023181)
# Compass: 0.09632030129432678
# LiDAR Data: [-5.3119483e+00  9.7656248e-06  6.9172680e-01 ...  4.3662108e-02
#  -7.0224315e-01  9.9439776e-01]
# Acceleration: Vector3D(x=0.421878, y=0.154701, z=9.809992)
# Gyroscope: Vector3D(x=-0.000093, y=0.000342, z=0.023326)
# Compass: 0.09869643300771713
# LiDAR Data: [-5.311953    0.          0.69172657 ...  0.04367187 -0.70223683
#   0.9943979 ]
# Acceleration: Vector3D(x=0.415587, y=0.162550, z=9.809948)
# Gyroscope: Vector3D(x=-0.000093, y=0.000341, z=0.023468)
# Compass: 0.10108599066734314
# LiDAR Data: [-5.3119626   0.          0.69172585 ...  0.04365234 -0.7022307
#   0.9943979 ]
# Acceleration: Vector3D(x=0.408242, y=0.159852, z=9.809964)
# Gyroscope: Vector3D(x=-0.000092, y=0.000340, z=0.023609)
# Compass: 0.10348864644765854
# LiDAR Data: [-5.341484   -0.191875    0.69601965 ...  0.08723632 -0.7022299
#   0.9943979 ]
# Acceleration: Vector3D(x=0.402169, y=0.163339, z=9.809916)
# Gyroscope: Vector3D(x=-0.000092, y=0.000339, z=0.023746)
# Compass: 0.10590577870607376
# LiDAR Data: [-5.3119335e+00 -9.7656248e-06  6.9172651e-01 ...  4.3642577e-02
#  -7.0221871e-01  9.9439806e-01]
# Acceleration: Vector3D(x=0.394740, y=0.165737, z=9.809960)
# Gyroscope: Vector3D(x=-0.000092, y=0.000337, z=0.023881)
# Compass: 0.10833587497472763
# LiDAR Data: [-5.3119483e+00 -1.9531250e-05  6.9172591e-01 ...  4.3662108e-02
#  -7.0221251e-01  9.9439806e-01]
# Acceleration: Vector3D(x=0.388363, y=0.166171, z=9.809973)
# Gyroscope: Vector3D(x=-0.000093, y=0.000336, z=0.024014)
# Compass: 0.11077918857336044
# LiDAR Data: [-5.3119483e+00  2.9296874e-05  6.9172698e-01 ...  1.3077149e-01
#  -7.0221740e-01  9.9439800e-01]
# Acceleration: Vector3D(x=0.380483, y=0.169944, z=9.809938)
# Gyroscope: Vector3D(x=-0.000092, y=0.000335, z=0.024144)
# Compass: 0.11323698610067368
# LiDAR Data: [-5.3414745  -0.1918457   0.69601965 ...  0.04368164 -0.70220107
#   0.9943981 ]
# Acceleration: Vector3D(x=0.375774, y=0.168357, z=9.809944)
# Gyroscope: Vector3D(x=-0.000091, y=0.000334, z=0.024272)
# Compass: 0.11570629477500916
# LiDAR Data: [-5.3119383e+00 -9.7656248e-06  6.9172502e-01 ...  4.3652344e-02
#  -7.0219535e-01  9.9439818e-01]
# Acceleration: Vector3D(x=0.367601, y=0.174748, z=9.809958)
# Gyroscope: Vector3D(x=-0.000092, y=0.000333, z=0.024398)
# Compass: 0.11818793416023254
# LiDAR Data: [-5.311953    0.          0.6917248  ...  0.04366211 -0.70218956
#   0.99439824]
# Acceleration: Vector3D(x=0.363375, y=0.171889, z=9.809946)
# Gyroscope: Vector3D(x=-0.000091, y=0.000332, z=0.024521)
# Compass: 0.12068115919828415
# LiDAR Data: [-5.3414893  -0.19186524  0.6960209  ...  0.17409179 -0.70220023
#   0.9943981 ]
# Acceleration: Vector3D(x=0.356493, y=0.178196, z=9.809999)
# Gyroscope: Vector3D(x=-0.000089, y=0.000332, z=0.024642)
# Compass: 0.12318770587444305
# LiDAR Data: [-5.341484   -0.191875    0.6960214  ...  0.04365234 -0.70217854
#   0.9943983 ]
# Acceleration: Vector3D(x=0.348550, y=0.175849, z=9.809917)
# Gyroscope: Vector3D(x=-0.000091, y=0.000330, z=0.024762)
# Compass: 0.12570585310459137
# LiDAR Data: [-5.3414745  -0.19185546  0.69602054 ...  0.04365234 -0.702173
#   0.99439836]
# Acceleration: Vector3D(x=0.344338, y=0.178098, z=9.809947)
# Gyroscope: Vector3D(x=-0.000090, y=0.000329, z=0.024878)
# Compass: 0.12823539972305298
# LiDAR Data: [-5.3119531e+00  9.7656248e-06  6.9172621e-01 ...  1.3074218e-01
#  -7.0217872e-01  9.9439830e-01]
# Acceleration: Vector3D(x=0.338039, y=0.178751, z=9.809986)
# Gyroscope: Vector3D(x=-0.000090, y=0.000328, z=0.024993)
# Compass: 0.13077615201473236
# LiDAR Data: [-4.8608494  -0.17458007  0.5223045  ...  0.04365234 -0.7021622
#   0.9943985 ]
# Acceleration: Vector3D(x=0.332329, y=0.183769, z=9.809938)
# Gyroscope: Vector3D(x=-0.000090, y=0.000327, z=0.025106)
# Compass: 0.1333283931016922
# LiDAR Data: [-4.8608594  -0.17461914  0.5223038  ...  0.08725586 -0.7021627
#   0.9943984 ]
# Acceleration: Vector3D(x=0.326844, y=0.185639, z=9.809962)
# Gyroscope: Vector3D(x=-0.000090, y=0.000326, z=0.025216)
# Compass: 0.13589239120483398
# LiDAR Data: [-5.311958    0.          0.69172436 ...  0.04365234 -0.70215195
#   0.99439853]
# Acceleration: Vector3D(x=0.320152, y=0.183282, z=9.809983)
# Gyroscope: Vector3D(x=-0.000089, y=0.000325, z=0.025325)
# Compass: 0.13846661150455475
# LiDAR Data: [-5.341484    0.19185546  0.6960231  ...  0.04367187 -0.70214707
#   0.9943986 ]
# Acceleration: Vector3D(x=0.314948, y=0.187058, z=9.809905)
# Gyroscope: Vector3D(x=-0.000089, y=0.000324, z=0.025431)
# Compass: 0.14105097949504852
# LiDAR Data: [-5.3119531e+00  9.7656248e-06  6.9172734e-01 ...  1.3075195e-01
#  -7.0215344e-01  9.9439853e-01]
# Acceleration: Vector3D(x=0.308881, y=0.189092, z=9.810018)
# Gyroscope: Vector3D(x=-0.000090, y=0.000323, z=0.025536)
# Compass: 0.14364618062973022
# LiDAR Data: [-5.3119431e+00 -9.7656248e-06  6.9172597e-01 ...  8.7236322e-02
#  -7.0214283e-01  9.9439865e-01]
# Acceleration: Vector3D(x=0.303975, y=0.190355, z=9.809920)
# Gyroscope: Vector3D(x=-0.000089, y=0.000322, z=0.025638)
# Compass: 0.14625167846679688
# LiDAR Data: [-5.3414793   0.19185546  0.6960207  ...  0.04367187 -0.70213217
#   0.99439865]
# Acceleration: Vector3D(x=0.298801, y=0.189788, z=9.809989)
# Gyroscope: Vector3D(x=-0.000087, y=0.000321, z=0.025739)
# Compass: 0.14886656403541565
# LiDAR Data: [-5.311953    0.          0.6917259  ...  0.13074218 -0.70213926
#   0.9943986 ]
# Acceleration: Vector3D(x=0.293482, y=0.192430, z=9.809920)
# Gyroscope: Vector3D(x=-0.000089, y=0.000321, z=0.025838)
# Compass: 0.15149113535881042
# LiDAR Data: [ 1.8562304   9.730703    1.2899873  ...  0.13076171 -0.70213455
#   0.99439865]
# Acceleration:LiDAR Data: [ 1.1416552   9.739482    1.5022498  ...  0.04365234 -0.70211846
#   0.9943988 ]
#  Vector3D(x=0.288182, y=0.195098, z=9.810019)
# Gyroscope: Vector3D(x=-0.000089, y=0.000320, z=0.025935)
# Compass: 0.1541268676519394
# Acceleration: Vector3D(x=0.282606, y=0.195940, z=9.809892)
# Gyroscope: Vector3D(x=-0.000088, y=0.000319, z=0.026030)
# Compass: 0.15677055716514587
# LiDAR Data: [-5.3119578e+00 -9.7656248e-06  6.9172573e-01 ...  4.3662108e-02
#  -7.0211357e-01  9.9439883e-01]
# Acceleration: Vector3D(x=0.276940, y=0.196194, z=9.810004)
# Gyroscope: Vector3D(x=-0.000088, y=0.000317, z=0.026124)
# Compass: 0.1594240814447403
# LiDAR Data: [-0.26058105  9.674121    1.4825575  ...  0.17407227 -0.7021278
#   0.99439865]
# Acceleration: Vector3D(x=0.274048, y=0.197924, z=9.809941)
# Gyroscope: Vector3D(x=-0.000089, y=0.000317, z=0.026216)
# Compass: 0.1620873510837555
# LiDAR Data: [-0.956748    9.658427    1.711372   ...  0.04364258 -0.7021044
#   0.9943989 ]
# Acceleration: Vector3D(x=0.268190, y=0.200797, z=9.809961)
# Gyroscope: Vector3D(x=-0.000088, y=0.000316, z=0.026305)
# Compass: 0.1647595316171646
# LiDAR Data: [-5.3119483e+00 -9.7656248e-06  6.9172651e-01 ...  8.7236322e-02
#  -7.0210648e-01  9.9439889e-01]
# Acceleration: Vector3D(x=0.263267, y=0.199737, z=9.809966)
# Gyroscope: Vector3D(x=-0.000088, y=0.000315, z=0.026394)
# Compass: 0.16743916273117065
# LiDAR Data: [-5.3119483e+00 -9.7656248e-06  6.9172627e-01 ...  8.7246090e-02
#  -7.0210212e-01  9.9439895e-01]
# Acceleration: Vector3D(x=0.256936, y=0.205291, z=9.809947)
# Gyroscope: Vector3D(x=-0.000088, y=0.000314, z=0.026481)
# Compass: 0.170128732919693
# LiDAR Data: [-5.341499   -0.19186524  0.6960227  ...  0.04364258 -0.7020915
#   0.994399  ]
# Acceleration: Vector3D(x=0.253938, y=0.198882, z=9.809997)
# Gyroscope: Vector3D(x=-0.000087, y=0.000313, z=0.026566)
# Compass: 0.17282675206661224
# LiDAR Data: [-5.311953    0.          0.6917281  ...  0.04365234 -0.70208776
#   0.994399  ]
# Acceleration: Vector3D(x=0.250123, y=0.205958, z=9.809932)
# Gyroscope: Vector3D(x=-0.000088, y=0.000312, z=0.026650)
# Compass: 0.17553217709064484
# LiDAR Data: [-5.3119431e+00  9.7656248e-06  6.9172627e-01 ...  8.7236322e-02
#  -7.0208973e-01  9.9439901e-01]
# Acceleration: Vector3D(x=0.244652, y=0.208909, z=9.809976)
# Gyroscope: Vector3D(x=-0.000086, y=0.000312, z=0.026731)
# Compass: 0.17824670672416687
# LiDAR Data: [-5.311943    0.          0.6917259  ...  0.17405273 -0.7020989
#   0.99439895]
# Acceleration: Vector3D(x=0.238609, y=0.206920, z=9.809962)
# Gyroscope: Vector3D(x=-0.000087, y=0.000311, z=0.026812)
# Compass: 0.1809682995080948
# LiDAR Data: [-5.3119335e+00  9.7656248e-06  6.9172597e-01 ...  2.1714844e-01
#  -7.0210171e-01  9.9439895e-01]
# Acceleration: Vector3D(x=0.236007, y=0.208136, z=9.809923)
# Gyroscope: Vector3D(x=-0.000087, y=0.000311, z=0.026891)
# Compass: 0.18369798362255096
# LiDAR Data: [-5.34147    -0.19186524  0.69602066 ...  0.04365234 -0.7020715
#   0.9943992 ]
# Acceleration: Vector3D(x=0.231725, y=0.207137, z=9.809992)
# Gyroscope: Vector3D(x=-0.000089, y=0.000310, z=0.026968)
# Compass: 0.18643571436405182
# LiDAR Data: [ 4.6698437   7.659033    1.5816438  ...  0.04365234 -0.7020677
#   0.99439925]
# Acceleration: Vector3D(x=0.228167, y=0.214936, z=9.810005)
# Gyroscope: Vector3D(x=-0.000088, y=0.000309, z=0.027044)
# Compass: 0.18918058276176453
# LiDAR Data: [ 3.9302342   7.6286716   1.513144   ...  0.04365234 -0.7020644
#   0.99439925]
# Acceleration: Vector3D(x=0.222507, y=0.211711, z=9.809895)
# Gyroscope: Vector3D(x=-0.000087, y=0.000309, z=0.027119)
# Compass: 0.1919335126876831
# LiDAR Data: [-5.311953    0.          0.6917264  ...  0.04365234 -0.7020604
#   0.99439925]
# Acceleration: Vector3D(x=0.217994, y=0.209557, z=9.809988)
# Gyroscope: Vector3D(x=-0.000088, y=0.000307, z=0.027192)
# Compass: 0.1946929693222046
# LiDAR Data: [-5.3119483   0.          0.691727   ...  0.04365234 -0.70205677
#   0.99439925]
# Acceleration: Vector3D(x=0.215681, y=0.218464, z=9.809958)
# Gyroscope: Vector3D(x=-0.000087, y=0.000307, z=0.027264)
# Compass: 0.19746053218841553
# LiDAR Data: [-5.34147    -0.19188476  0.69602096 ...  0.13071288 -0.70206666
#   0.99439925]
# Acceleration: Vector3D(x=0.210570, y=0.216478, z=9.809958)
# Gyroscope: Vector3D(x=-0.000087, y=0.000306, z=0.027334)
# Compass: 0.20023468136787415
# LiDAR Data: [-5.3414893  -0.19186524  0.6960204  ...  0.08723632 -0.7020562
#   0.9943993 ]
# Acceleration: Vector3D(x=0.206675, y=0.214274, z=9.809988)
# Gyroscope: Vector3D(x=-0.000086, y=0.000306, z=0.027403)
# Compass: 0.20301517844200134
# LiDAR Data: [ 6.0654054   7.331826    1.4577214  ...  0.04364258 -0.7020465
#   0.9943994 ]
# Acceleration: Vector3D(x=0.203437, y=0.218332, z=9.809929)
# Gyroscope: Vector3D(x=-0.000089, y=0.000306, z=0.027471)
# Compass: 0.20580294728279114
# LiDAR Data: [-5.3414745   0.191875    0.69602066 ...  0.04366211 -0.702043
#   0.99439937]
# Acceleration: Vector3D(x=0.199143, y=0.218810, z=9.809978)
# Gyroscope: Vector3D(x=-0.000086, y=0.000304, z=0.027537)
# Compass: 0.20859688520431519
# LiDAR Data: [-1.2900342   7.4907713   1.1644363  ...  0.04365234 -0.7020396
#   0.9943994 ]
# Acceleration: Vector3D(x=0.195727, y=0.220398, z=9.809938)
# Gyroscope: Vector3D(x=-0.000087, y=0.000303, z=0.027603)
# Compass: 0.21139730513095856
# LiDAR Data: [ 3.7730224   7.323545    1.4526391  ...  0.04365234 -0.7020362
#   0.9943994 ]
# Acceleration: Vector3D(x=0.192057, y=0.220789, z=9.809972)
# Gyroscope: Vector3D(x=-0.000085, y=0.000303, z=0.027667)
# Compass: 0.21420511603355408
# LiDAR Data: [ 3.0730224   7.1896873   1.3786844  ...  0.08722656 -0.70203954
#   0.9943994 ]
# Acceleration: Vector3D(x=0.188699, y=0.221129, z=9.809973)
# Gyroscope: Vector3D(x=-0.000087, y=0.000303, z=0.027730)
# Compass: 0.21701839566230774
# LiDAR Data: [-5.3119431e+00 -1.9531250e-05  6.9172573e-01 ...  2.1711914e-01
#  -7.0205748e-01  9.9439931e-01]
# Acceleration: Vector3D(x=0.184703, y=0.222913, z=9.809954)
# Gyroscope: Vector3D(x=-0.000086, y=0.000302, z=0.027791)
# Compass: 0.2198375165462494
# LiDAR Data: [ 1.630498    7.1437497   1.2920321  ...  0.08724609 -0.70203334
#   0.9943995 ]
# Acceleration: Vector3D(x=0.181387, y=0.222011, z=9.810002)
# Gyroscope: Vector3D(x=-0.000088, y=0.000301, z=0.027852)
# Compass: 0.22266334295272827
# LiDAR Data: [-5.1025      7.436084    1.5901922  ...  0.13070312 -0.7020377
#   0.9943994 ]
# Acceleration: Vector3D(x=0.177358, y=0.226416, z=9.809909)
# Gyroscope: Vector3D(x=-0.000085, y=0.000301, z=0.027911)
# Compass: 0.225495383143425
# LiDAR Data: [ 0.06365234  7.0925193   1.2506573  ...  0.04364258 -0.7020205
#   0.99439955]
# Acceleration: Vector3D(x=0.175858, y=0.226413, z=9.809977)
# Gyroscope: Vector3D(x=-0.000087, y=0.000300, z=0.027969)
# Compass: 0.22833240032196045
# LiDAR Data: [-0.70086914  7.0752735   1.2536683  ...  0.08725586 -0.7020246
#   0.99439955]
# Acceleration: Vector3D(x=0.170728, y=0.225996, z=9.809949)
# Gyroscope: Vector3D(x=-0.000084, y=0.000299, z=0.028026)
# Compass: 0.23117473721504211
# LiDAR Data: [-1.4786962   7.060547    1.2719753  ...  0.04364258 -0.7020146
#   0.9943996 ]
# Acceleration: Vector3D(x=0.168001, y=0.227601, z=9.809983)
# Gyroscope: Vector3D(x=-0.000086, y=0.000299, z=0.028082)
# Compass: 0.23402325809001923
# LiDAR Data: [-2.293042    7.057207    1.3084147  ...  0.08722656 -0.7020188
#   0.99439955]
# Acceleration: Vector3D(x=0.165276, y=0.230510, z=9.809953)
# Gyroscope: Vector3D(x=-0.000086, y=0.000298, z=0.028137)
# Compass: 0.23687726259231567
# LiDAR Data: [-5.34147     0.19185546  0.69602036 ...  0.08724609 -0.70201606
#   0.9943996 ]
# Acceleration: Vector3D(x=0.161397, y=0.226002, z=9.809953)
# Gyroscope: Vector3D(x=-0.000086, y=0.000299, z=0.028191)
# Compass: 0.23973631858825684
# LiDAR Data: [-3.7824461   7.028945    1.4074485  ...  0.04364258 -0.70200604
#   0.9943997 ]
# Acceleration: Vector3D(x=0.159290, y=0.231375, z=9.809953)
# Gyroscope: Vector3D(x=-0.000086, y=0.000297, z=0.028243)
# Compass: 0.24260054528713226
# LiDAR Data: [ 9.054506    2.4989061   1.438957   ...  0.04364258 -0.70200306
#   0.9943997 ]
# Acceleration: Vector3D(x=0.155091, y=0.232143, z=9.809971)
# Gyroscope: Vector3D(x=-0.000085, y=0.000297, z=0.028296)
# Compass: 0.24547049403190613
# LiDAR Data: [ 7.7484374   2.7503905   1.4497751  ...  0.04365234 -0.7020002
#   0.9943997 ]
# Acceleration: Vector3D(x=0.153320, y=0.231029, z=9.809982)
# Gyroscope: Vector3D(x=-0.000085, y=0.000296, z=0.028346)
# Compass: 0.2483453005552292
# LiDAR Data: [ 6.9526854   2.7527442   1.3185357  ...  0.08723632 -0.70200527
#   0.9943997 ]
# Acceleration: Vector3D(x=0.149744, y=0.232969, z=9.809958)
# Gyroscope: Vector3D(x=-0.000086, y=0.000296, z=0.028396)
# Compass: 0.251224547624588
# LiDAR Data: [ 6.1584764   2.6978905   1.1855344  ...  0.08722656 -0.70200276
#   0.9943997 ]
# Acceleration: Vector3D(x=0.147078, y=0.233406, z=9.809967)
# Gyroscope: Vector3D(x=-0.000087, y=0.000295, z=0.028445)
# Compass: 0.25410932302474976
# LiDAR Data: [ 5.8878417   2.331162    1.116598   ...  0.04363281 -0.7019933
#   0.9943997 ]
# Acceleration: Vector3D(x=0.142889, y=0.232969, z=9.809894)
# Gyroscope: Vector3D(x=-0.000084, y=0.000295, z=0.028493)
# Compass: 0.25699853897094727
# LiDAR Data: [ 4.5675097   2.6188476   0.806574   ...  0.04363281 -0.70199025
#   0.99439985]
# Acceleration: Vector3D(x=0.143006, y=0.236586, z=9.810025)
# Gyroscope: Vector3D(x=-0.000086, y=0.000294, z=0.028540)
# Compass: 0.2598927319049835
# LiDAR Data: [ 4.2946286   2.2615623   0.7435616  ...  0.04364258 -0.701988
#   0.99439985]
# Acceleration: Vector3D(x=0.137471, y=0.236553, z=9.809933)
# Gyroscope: Vector3D(x=-0.000085, y=0.000294, z=0.028586)
# Compass: 0.26279133558273315
# LiDAR Data: [ 2.9890332   2.5182421   0.5987505  ...  0.04364258 -0.7019855
#   0.99439985]
# Acceleration: Vector3D(x=0.136462, y=0.235322, z=9.809977)
# Gyroscope: Vector3D(x=-0.000084, y=0.000293, z=0.028631)
# Compass: 0.2656935453414917
# LiDAR Data: [ 2.6637304   2.2442186   0.6141638  ...  0.08724609 -0.7019905
#   0.9943998 ]
# Acceleration: Vector3D(x=0.133761, y=0.239749, z=9.809937)
# Gyroscope: Vector3D(x=-0.000086, y=0.000293, z=0.028675)
# Compass: 0.26860082149505615
# LiDAR Data: [ 1.9282714   2.1675098   0.51154095 ...  0.04364258 -0.70198065
#   0.9943999 ]
# Acceleration: Vector3D(x=0.130433, y=0.236590, z=9.810001)
# Gyroscope: Vector3D(x=-0.000085, y=0.000293, z=0.028719)
# Compass: 0.2715121805667877
# LiDAR Data: [ 1.1057812   2.1463475   0.4257331  ...  0.04365234 -0.701979
#   0.9943999 ]
# Acceleration: Vector3D(x=0.128480, y=0.239553, z=9.809917)
# Gyroscope: Vector3D(x=-0.000086, y=0.000292, z=0.028761)
# Compass: 0.27442705631256104
# LiDAR Data: [ 0.32691404  2.125752    0.37923416 ...  0.08721679 -0.70198387
#   0.99439985]
# Acceleration: Vector3D(x=0.125478, y=0.237634, z=9.809957)
# Gyroscope: Vector3D(x=-0.000087, y=0.000292, z=0.028803)
# Compass: 0.27734753489494324
# LiDAR Data: [-0.44580567  2.128623    0.3834944  ...  0.08722656 -0.70198137
#   0.9943999 ]
# Acceleration: Vector3D(x=0.123251, y=0.240712, z=9.809976)
# Gyroscope: Vector3D(x=-0.000085, y=0.000292, z=0.028844)
# Compass: 0.28027135133743286
# LiDAR Data: [-1.2457422   2.128164    0.4348133  ...  0.04366211 -0.7019721
#   0.99439996]
# Acceleration: Vector3D(x=0.121893, y=0.242255, z=9.809956)
# Gyroscope: Vector3D(x=-0.000086, y=0.000291, z=0.028884)
# Compass: 0.283199667930603
# LiDAR Data: [-2.0734375   2.0921288   0.51936156 ...  0.13072266 -0.70198464
#   0.99439985]
# Acceleration: Vector3D(x=0.118344, y=0.241850, z=9.809971)
# Gyroscope: Vector3D(x=-0.000085, y=0.000291, z=0.028924)
# Compass: 0.28613173961639404
# LiDAR Data: [ 6.531894   -0.11726562  1.1519356  ...  0.04365234 -0.70196784
#   0.9944    ]
# Acceleration: Vector3D(x=0.116141, y=0.241066, z=9.809957)
# Gyroscope: Vector3D(x=-0.000085, y=0.000290, z=0.028963)
# Compass: 0.2890673279762268
# LiDAR Data: [ 1.1429394   9.7503805   1.7310263  ...  0.04364258 -0.7019661
#   0.9944    ]
# Acceleration: Vector3D(x=0.114206, y=0.242827, z=9.809903)
# Gyroscope: Vector3D(x=-0.000085, y=0.000290, z=0.029000)
# Compass: 0.29200711846351624
# LiDAR Data: [ 0.0879541   9.798828    1.7278658  ...  0.13070312 -0.70197845
#   0.99439996]
# Acceleration: Vector3D(x=0.112134, y=0.244645, z=9.810019)
# Gyroscope: Vector3D(x=-0.000084, y=0.000289, z=0.029038)
# Compass: 0.2949504256248474
# LiDAR Data: [ 4.0694284  -0.219375    0.7185906  ...  0.04362305 -0.70172745
#   0.99440193]
# Acceleration: Vector3D(x=0.087409, y=0.176117, z=9.985207)
# Gyroscope: Vector3D(x=0.014610, y=-0.006754, z=0.028299)
# Compass: 0.29782021045684814
# LiDAR Data: [ 3.2753613  -0.1765625   0.57837987 ...  0.04352539 -0.6999457
#   0.99441606]
# Acceleration: Vector3D(x=0.092267, y=0.178894, z=9.956452)
# Gyroscope: Vector3D(x=0.014744, y=-0.007227, z=0.028266)
# Compass: 0.30060601234436035
# LiDAR Data: [ 2.4522655  -0.3097949   0.43583572 ...  0.03460937 -0.5567064
#   0.99555624]
# Acceleration: Vector3D(x=-1.964646, y=0.963092, z=17.173424)
# Gyroscope: Vector3D(x=0.061497, y=-0.038075, z=0.026771)
# Compass: 0.30770495533943176
# LiDAR Data: [ 1.6286181  -0.26544923  0.29095885 ...  0.0412793  -0.66370726
#   0.9947044 ]
# Acceleration: Vector3D(x=1.030287, y=0.924270, z=3.426039)
# Gyroscope: Vector3D(x=0.046976, y=-0.014547, z=0.019891)
# Compass: 0.31216636300086975
# LiDAR Data: [ 0.8115429  -0.32131836  0.15390289 ...  0.08486328 -0.68312895
#   0.99454993]
# Acceleration:LiDAR Data: [ 0.01361816 -0.3031738   0.0535083  ...  0.04276367 -0.68786925
#   0.9945122 ]
#  Vector3D(x=0.530220, y=0.807582, z=8.954806)
# Gyroscope: Vector3D(x=0.034293, y=-0.001228, z=0.019917)
# Compass: 0.31646600365638733
# Acceleration: Vector3D(x=0.059571, y=1.477747, z=7.811469)
# Gyroscope: Vector3D(x=0.420797, y=0.258821, z=0.164526)
# Compass: 0.3263137936592102
# LiDAR Data: [-0.7545996  -0.3145703   0.14415526 ...  0.08255859 -0.6643683
#   0.9946992 ]
# Acceleration: Vector3D(x=-0.807148, y=1.298693, z=10.283085)
# Gyroscope: Vector3D(x=0.041639, y=0.036859, z=0.060007)
# Compass: 0.33733808994293213
# LiDAR Data: [-1.5352832  -0.33594725  0.2771161  ...  0.03977539 -0.639848
#   0.9948943 ]
# Acceleration: Vector3D(x=0.033131, y=1.157746, z=10.850876)
# Gyroscope: Vector3D(x=0.008918, y=0.006599, z=0.036456)
# Compass: 0.34200409054756165
# LiDAR Data: [-2.3339062  -0.3375      0.41581053 ...  0.24371094 -0.65822875
#   0.994748  ]
# Collision Detected!
# Acceleration: Vector3D(x=-11.711251, y=0.630014, z=17.929083)
# Gyroscope: Vector3D(x=0.225871, y=0.112289, z=-0.462892)
# Compass: 0.33291277289390564
# LiDAR Data: [ 8.287665    0.14879882  1.4615753  ...  0.04617187 -0.74287045
#   0.99407464]
# Acceleration: Vector3D(x=-81.491028, y=-5.421940, z=5.326779)
# Gyroscope: Vector3D(x=-0.067689, y=-0.051290, z=-0.398251)
# Compass: 0.28434860706329346
# LiDAR Data: [ 0.8333789   7.109668    1.2622058  ...  0.04726562 -0.7600253
#   0.99393815]
# Acceleration: Vector3D(x=10.595409, y=1.624539, z=8.390308)
# Gyroscope: Vector3D(x=-0.026791, y=-0.031106, z=0.019265)
# Compass: 0.27306491136550903
# LiDAR Data: [-2.784082   -0.4026074   0.496015   ...  0.14441405 -0.7755261
#   0.993815  ]
# Acceleration: Vector3D(x=8.659998, y=1.004658, z=8.941300)
# Gyroscope: Vector3D(x=-0.007679, y=-0.014327, z=0.002512)
# Compass: 0.2735617756843567
# LiDAR Data: [ 0.57129884  7.0566306   1.248345   ...  0.09657227 -0.7771823
#   0.99380183]
# Acceleration: Vector3D(x=4.461987, y=0.502302, z=9.464536)
# Gyroscope: Vector3D(x=-0.003526, y=-0.005142, z=0.011800)
# Compass: 0.27475327253341675
# LiDAR Data: [-2.9350097  -0.4244531   0.5229053  ...  0.04819336 -0.7751733
#   0.9938178 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=-8.600451, y=-0.353034, z=10.011693)
# Gyroscope: Vector3D(x=-0.002449, y=-0.000280, z=-0.011582)
# Compass: 0.27165481448173523
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9422948  -0.42547852  0.5242029  ...  0.04804688 -0.7725427
#   0.9938387 ]
# Collision Detected!
# Acceleration: Vector3D(x=-0.542441, y=0.671168, z=9.959316)
# Gyroscope: Vector3D(x=0.001137, y=-0.004018, z=-0.010077)
# Compass: 0.271056205034256
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.942041   -0.42545897  0.52415466 ...  0.14461914 -0.77665097
#   0.993806  ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.213752, y=0.374732, z=9.796221)
# Gyroscope: Vector3D(x=-0.001515, y=-0.001539, z=-0.006618)
# Compass: 0.27069956064224243
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9414842  -0.42537108  0.5240579  ...  0.04807617 -0.773219
#   0.99383336]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.277318, y=0.423275, z=9.795274)
# Gyroscope: Vector3D(x=-0.000416, y=-0.000861, z=-0.005840)
# Compass: 0.2705383598804474
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.941328   -0.4253613   0.52403134 ...  0.04807617 -0.7734421
#   0.9938316 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.261538, y=0.305862, z=9.814137)
# Gyroscope: Vector3D(x=0.001077, y=-0.000914, z=-0.007176)
# Compass: 0.2700541913509369
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9412303  -0.425332    0.52401274 ...  0.04810547 -0.773685
#   0.9938296 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.253278, y=0.465347, z=9.784944)
# Gyroscope: Vector3D(x=-0.000275, y=-0.000402, z=0.004049)
# Compass: 0.26981478929519653
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9412498  -0.425332    0.5240149  ...  0.04810547 -0.7737283
#   0.99382925]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.244806, y=0.334918, z=9.795396)
# Gyroscope: Vector3D(x=-0.002230, y=-0.000238, z=-0.000604)
# Compass: 0.26955997943878174
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9412205  -0.425332    0.52401215 ...  0.0480957  -0.77364135
#   0.99382997]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.273774, y=0.463540, z=9.810901)
# Gyroscope: Vector3D(x=0.000515, y=-0.001830, z=-0.020945)
# Compass: 0.2693403363227844
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9413965  -0.42535156  0.5240387  ...  0.04810547 -0.7737509
#   0.9938291 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.233920, y=0.335566, z=9.786793)
# Gyroscope: Vector3D(x=-0.002708, y=-0.000076, z=0.000054)
# Compass: 0.2691263258457184
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.579873    7.1625485   1.2670844  ...  0.04811523 -0.7736438
#   0.99382997]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.257558, y=0.332112, z=9.807376)
# Gyroscope: Vector3D(x=0.002712, y=-0.000914, z=-0.009356)
# Compass: 0.26864349842071533
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9413965  -0.42538086  0.52404237 ...  0.09635742 -0.7754645
#   0.99381554]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.240802, y=0.379192, z=9.797116)
# Gyroscope: Vector3D(x=-0.003378, y=0.000394, z=0.001576)
# Compass: 0.2682655155658722
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.5805371   7.1706543   1.2685162  ...  0.09635742 -0.77537715
#   0.9938162 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.261249, y=0.434588, z=9.804028)
# Gyroscope: Vector3D(x=-0.002168, y=0.000075, z=-0.001363)
# Compass: 0.26806777715682983
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9413867  -0.42537108  0.5240417  ...  0.2900293  -0.78334594
#   0.99375284]
# Collision Detected!Acceleration: Vector3D(x=0.240507, y=0.331911, z=9.793247)
# Gyroscope: Vector3D(x=-0.000172, y=-0.000729, z=-0.010045)
# Compass: 0.26778995990753174
#
# LiDAR Data: [-2.9413476  -0.42534178  0.52403504 ...  0.04810547 -0.7734833
#   0.9938312 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.275962, y=0.539552, z=9.798496)
# Gyroscope: Vector3D(x=-0.003318, y=0.000570, z=0.001821)
# Compass: 0.2679480314254761
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9416308  -0.42540038  0.52408504 ...  0.04808594 -0.77348995
#   0.9938312 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.234432, y=0.214458, z=9.803429)
# Gyroscope: Vector3D(x=-0.000424, y=0.000668, z=-0.006949)
# Compass: 0.2675066590309143
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9416015  -0.4253906   0.5240811  ...  0.1447168  -0.7771811
#   0.99380183]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.241414, y=0.464169, z=9.767467)
# Gyroscope: Vector3D(x=-0.000488, y=0.001446, z=-0.005892)
# Compass: 0.26754656434059143
# LiDAR Data: [-2.9416602  -0.42540038  0.5240918  ...  0.04805664 -0.77302
#   0.993835  ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.273703, y=0.446816, z=9.826900)
# Gyroscope: Vector3D(x=0.005805, y=0.000491, z=0.030379)
# Compass: 0.26753076910972595
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9418554  -0.42541993  0.52412444 ...  0.0480664  -0.7730209
#   0.9938349 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.247452, y=0.249774, z=9.801497)
# Gyroscope: Vector3D(x=-0.002972, y=0.000270, z=-0.001424)
# Compass: 0.2671959698200226
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.941953   -0.42543945  0.52414274 ...  0.0480664  -0.7729654
#   0.9938354 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.240507, y=0.378518, z=9.788204)
# Gyroscope: Vector3D(x=-0.001262, y=0.000506, z=-0.004437)
# Compass: 0.266806036233902
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9419725  -0.42544922  0.52414733 ...  0.09625977 -0.77456325
#   0.99382263]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.237544, y=0.340815, z=9.809268)
# Gyroscope: Vector3D(x=0.001629, y=-0.000103, z=-0.007803)
# Compass: 0.26633766293525696
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9418457  -0.42541993  0.524122   ...  0.04803711 -0.7726071
#   0.9938382 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.252104, y=0.459709, z=9.806211)
# Gyroscope: Vector3D(x=-0.000614, y=0.000794, z=-0.010490)
# Compass: 0.26601022481918335
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9417284  -0.42541015  0.52410275 ...  0.04804688 -0.77262694
#   0.9938381 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.275999, y=0.340792, z=9.797949)
# Gyroscope: Vector3D(x=-0.003526, y=0.000738, z=-0.001215)
# Compass: 0.26565971970558167
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.31838867  7.0894723   1.2513242  ...  0.09624023 -0.77447754
#   0.99382335]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.245626, y=0.461791, z=9.797274)
# Gyroscope: Vector3D(x=0.002812, y=-0.000797, z=-0.013301)
# Compass: 0.2654378116130829
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.5820605   7.18957     1.2718637  ...  0.04801758 -0.7726236
#   0.993838  ]
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.5823828   7.193408    1.2725437  ...  0.0962207  -0.77430695
#   0.9938247 ]
# Collision Detected!
# Acceleration: Vector3D(x=0.190081, y=0.305911, z=9.792309)
# Gyroscope: Vector3D(x=0.001499, y=0.000770, z=0.003450)
# Compass: 0.2650251090526581
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.311693, y=0.454913, z=9.786077)
# Gyroscope: Vector3D(x=0.000485, y=-0.001135, z=0.001944)
# Compass: 0.26497822999954224
# Collision Detected!
# LiDAR Data: [ 0.31841797  7.090332    1.2514786  ...  0.04801758 -0.77221036
#   0.9938413 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.259320, y=0.306900, z=9.798908)
# Gyroscope: Vector3D(x=0.000459, y=0.000420, z=-0.008625)
# Compass: 0.26465076208114624
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9421191  -0.42544922  0.52417237 ...  0.04799804 -0.77190644
#   0.9938438 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.229463, y=0.472704, z=9.813057)
# Gyroscope: Vector3D(x=0.001374, y=-0.000398, z=-0.010719)
# Compass: 0.264599472284317
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 8.168437    1.031914    1.2613062  ...  0.09614258 -0.77368313
#   0.9938296 ]
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.192279, y=0.475190, z=9.795678)
# Gyroscope: Vector3D(x=0.001230, y=0.001277, z=0.007263)
# Compass: 0.2649552524089813
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9420116  -0.42544922  0.5241519  ...  0.09612305 -0.77358913
#   0.9938304 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.346960, y=0.293505, z=9.792500)
# Gyroscope: Vector3D(x=-0.000245, y=-0.000088, z=-0.001397)
# Compass: 0.26498231291770935
# LiDAR Data: [-2.943838   -0.42574218  0.455672   ...  0.28926757 -0.78134334
#   0.99376875]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.198116, y=0.275475, z=9.802855)
# Gyroscope: Vector3D(x=-0.004704, y=0.001086, z=0.002765)
# Compass: 0.2646295428276062
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.32557616  7.2496777   1.1117285  ...  0.28916016 -0.78102875
#   0.99377126]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.246999, y=0.552108, z=9.812458)
# Gyroscope: Vector3D(x=0.005944, y=0.000021, z=0.030854)
# Compass: 0.2647523581981659
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9428222  -0.4255664   0.5242981  ...  0.09609375 -0.7731729
#   0.9938337 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.250776, y=0.218039, z=9.798841)
# Gyroscope: Vector3D(x=-0.002395, y=0.000157, z=0.000322)
# Compass: 0.26436278223991394
# Collision Detected!
# LiDAR Data: [-2.9428906  -0.42558593  0.52430874 ...  0.04794922 -0.7712234
#   0.9938492 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.208280, y=0.380774, z=9.805262)
# Gyroscope: Vector3D(x=-0.001108, y=-0.000182, z=-0.005521)
# Compass: 0.2638428807258606
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.94249    -0.42552733  0.5242395  ...  0.14427733 -0.7749438
#   0.99381965]
# Collision Detected!
# ...
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.226275, y=0.193121, z=9.796984)
# Gyroscope: Vector3D(x=-0.000145, y=0.000550, z=-0.007664)
# Compass: 0.22568058967590332
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.999658   -0.54435545  0.53756166 ...  0.04782226 -0.76903194
#   0.9938666 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.236627, y=0.389865, z=9.804046)
# Gyroscope: Vector3D(x=-0.003802, y=0.000705, z=-0.000647)
# Compass: 0.2253313809633255
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9823632  -0.43128905  0.53134096 ...  0.04779297 -0.76895505
#   0.9938672 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.234247, y=0.382371, z=9.802829)
# Gyroscope: Vector3D(x=-0.002857, y=-0.001611, z=-0.010232)
# Compass: 0.22500622272491455
# LiDAR Data: [-2.9819825  -0.43123046  0.53127533 ...  0.14387695 -0.7726556
#   0.99383783]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.260544, y=0.393231, z=9.801903)
# Gyroscope: Vector3D(x=0.000037, y=-0.000156, z=-0.002888)
# Compass: 0.22462280094623566
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9820018  -0.43124998  0.53127563 ...  0.04779297 -0.7689517
#   0.9938673 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.229667, y=0.420520, z=9.801908)
# Gyroscope: Vector3D(x=-0.001428, y=-0.000661, z=-0.015330)
# Compass: 0.22439710795879364
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9825683  -0.43132812  0.53137785 ...  0.09578124 -0.7708398
#   0.99385226]
# Collision Detected!Acceleration: Vector3D(x=0.206983, y=0.429476, z=9.798887)
# Gyroscope: Vector3D(x=-0.000684, y=-0.002228, z=0.000673)
# Compass: 0.22438237071037292
#
# LiDAR Data: [-2.9837205  -0.4314746   0.53158265 ...  0.14391601 -0.7728335
#   0.9938364 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.315130, y=0.265116, z=9.784484)
# Gyroscope: Vector3D(x=-0.004452, y=0.000820, z=0.001590)
# Compass: 0.2241012006998062
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9837499  -0.43149412  0.53158903 ...  0.04780274 -0.76894134
#   0.9938674 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.202377, y=0.453400, z=9.810503)
# Gyroscope: Vector3D(x=0.001356, y=-0.000190, z=0.024802)
# Compass: 0.22398047149181366
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9847069  -0.43162107  0.5317578  ...  0.09576172 -0.7707547
#   0.9938529 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.236183, y=0.332485, z=9.804097)
# Gyroscope: Vector3D(x=0.000273, y=0.000333, z=-0.006022)
# Compass: 0.22366735339164734
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9848046  -0.43164062  0.53177613 ...  0.09577148 -0.77078766
#   0.9938527 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.256213, y=0.430397, z=9.797441)
# Gyroscope: Vector3D(x=0.004147, y=-0.000852, z=-0.011806)
# Compass: 0.22346088290214539
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9857714  -0.4317871   0.53194946 ...  0.04780274 -0.7690048
#   0.99386686]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.237008, y=0.463976, z=9.799891)
# Gyroscope: Vector3D(x=-0.000445, y=0.000542, z=-0.006996)
# Compass: 0.2236367166042328
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.988203   -0.43214843  0.5323822  ...  0.04780274 -0.7690954
#   0.99386615]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.231904, y=0.276487, z=9.795148)
# Gyroscope: Vector3D(x=0.002742, y=-0.000571, z=-0.010809)
# Compass: 0.2234869748353958
# LiDAR Data: [-2.989004  -0.4322363  0.5325238 ...  0.0478125 -0.7690408  0.9938666]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.234670, y=0.340872, z=9.796634)
# Gyroscope: Vector3D(x=-0.004106, y=0.000841, z=-0.000218)
# Compass: 0.22327521443367004
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9892187  -0.43228516  0.5325641  ...  0.04780274 -0.76892334
#   0.9938675 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.253055, y=0.402829, z=9.809545)
# Gyroscope: Vector3D(x=0.004047, y=-0.001118, z=-0.009475)
# Compass: 0.2229236513376236
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9853907  -0.5417773   0.53500366 ...  0.0478125  -0.76897764
#   0.9938671 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.237194, y=0.441388, z=9.791094)
# Gyroscope: Vector3D(x=-0.005497, y=0.001088, z=0.002994)
# Compass: 0.22295089066028595
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.991289   -0.43257812  0.5329321  ...  0.33622068 -0.78059417
#   0.9937748 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.237973, y=0.274040, z=9.801396)
# Gyroscope: Vector3D(x=-0.003672, y=0.000644, z=0.001758)
# Compass: 0.22253158688545227
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.33405274  7.437939    1.3128302  ...  0.0477832  -0.76882046
#   0.99386835]
# Collision Detected!
# Acceleration: Vector3D(x=0.241260, y=0.433423, z=9.808635)
# Gyroscope: Vector3D(x=0.001307, y=-0.000893, z=-0.008426)
# Compass: 0.2223089337348938
# Collision Detected!
# LiDAR Data: [-2.9834666  -0.541416    0.5346622  ...  0.09579101 -0.7707617
#   0.99385285]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.231330, y=0.324692, z=9.794003)
# Gyroscope: Vector3D(x=-0.001578, y=0.000581, z=-0.004218)
# Compass: 0.22200676798820496
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9919238  -0.43265623  0.53304595 ...  0.0478125  -0.76888394
#   0.9938678 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.248395, y=0.453628, z=9.796727)
# Gyroscope: Vector3D(x=-0.003540, y=0.000585, z=0.001918)
# Compass: 0.22192445397377014
# Collision Detected!
# LiDAR Data: [-2.9931152  -0.43283203  0.5332553  ...  0.19199218 -0.77450466
#   0.9938231 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.227466, y=0.258815, z=9.804749)
# Gyroscope: Vector3D(x=-0.000658, y=-0.000556, z=-0.003468)
# Compass: 0.22143377363681793
# Collision Detected!
# LiDAR Data: [-2.992324   -0.43271482  0.53311676 ...  0.04780274 -0.7688269
#   0.9938683 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.258646, y=0.476794, z=9.795869)
# Gyroscope: Vector3D(x=0.002681, y=-0.000576, z=-0.009599)
# Compass: 0.22122444212436676
# Collision Detected!
# LiDAR Data: [-2.9931934  -0.43284178  0.53326935 ...  0.04779297 -0.7688089
#   0.9938684 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.230616, y=0.369596, z=9.802422)
# Gyroscope: Vector3D(x=-0.003403, y=0.000461, z=0.002040)
# Compass: 0.22106683254241943
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.06439453  7.1749997   1.2651956  ...  0.0478125  -0.76882565
#   0.99386823]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.234101, y=0.303636, z=9.798381)
# Gyroscope: Vector3D(x=-0.001200, y=0.000600, z=-0.004812)
# Compass: 0.22065654397010803
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.993457   -0.43288085  0.5333166  ...  0.09578124 -0.77059263
#   0.9938542 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.245480, y=0.369726, z=9.799315)
# Gyroscope: Vector3D(x=-0.003141, y=0.001009, z=-0.001123)
# Compass: 0.2201390564441681
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9929297  -0.43280274  0.53322357 ...  0.09575195 -0.7705026
#   0.99385494]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.230549, y=0.394361, z=9.803223)
# Gyroscope: Vector3D(x=-0.001577, y=0.000134, z=-0.001632)
# Compass: 0.2198588252067566
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9926074  -0.43277344  0.5331683  ...  0.04779297 -0.7686624
#   0.9938696 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.233489, y=0.402842, z=9.798184)
# Gyroscope: Vector3D(x=0.000472, y=-0.001329, z=0.007999)
# Compass: 0.21974729001522064
# Collision Detected!
# LiDAR Data: [-2.9927537  -0.43279296  0.5331915  ...  0.09573242 -0.7704654
#   0.9938552 ]
# Collision Detected!
# Acceleration: Vector3D(x=0.257500, y=0.408111, z=9.808048)
# Gyroscope: Vector3D(x=0.001494, y=0.000291, z=-0.006401)
# Compass: 0.21958892047405243
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9820898  -0.54115236  0.5344406  ...  0.09577148 -0.7705978
#   0.9938541 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.242464, y=0.458626, z=9.790706)
# Gyroscope: Vector3D(x=0.004159, y=-0.000697, z=-0.011160)
# Compass: 0.21971283853054047
# Collision Detected!
# LiDAR Data: [-2.995371   -0.43316406  0.53365785 ...  0.0477832  -0.76882076
#   0.9938683 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.244717, y=0.454674, z=9.796999)
# Gyroscope: Vector3D(x=-0.000618, y=-0.000071, z=-0.014964)
# Compass: 0.22009865939617157
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9986913  -0.43364257  0.5342523  ...  0.04779297 -0.76885194
#   0.99386805]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.226340, y=0.183248, z=9.798663)
# Gyroscope: Vector3D(x=-0.001605, y=0.000217, z=-0.003169)
# Compass: 0.21980580687522888
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.33696288  7.503105    1.3243334  ...  0.09575195 -0.77057767
#   0.99385434]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.253121, y=0.532756, z=9.804271)
# Gyroscope: Vector3D(x=-0.000249, y=0.000569, z=-0.008355)
# Compass: 0.21995992958545685
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-3.0015428  -0.43408203  0.5347604  ...  0.14383788 -0.7725479
#   0.9938387 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.227469, y=0.171001, z=9.801400)
# Gyroscope: Vector3D(x=0.000298, y=0.000358, z=-0.007937)
# Compass: 0.2193773090839386
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9780762  -0.5404394   0.5336801  ...  0.04779297 -0.7687802
#   0.99386865]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.236772, y=0.411351, z=9.795139)
# Gyroscope: Vector3D(x=0.002887, y=-0.000807, z=-0.009764)
# Compass: 0.21901053190231323
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [ 0.33783203  7.522734    1.3277997  ...  0.09576172 -0.7705371
#   0.99385464]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.225716, y=0.363918, z=9.799796)
# Gyroscope: Vector3D(x=-0.001637, y=-0.000003, z=-0.004215)
# Compass: 0.21863602101802826
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-3.000205   -0.4338574   0.534519   ...  0.09573242 -0.7704315
#   0.99385554]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.266296, y=0.464242, z=9.798694)
# Gyroscope: Vector3D(x=0.002817, y=-0.000618, z=-0.009569)
# Compass: 0.2185554802417755
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-3.00125    -0.43401366  0.5347064  ...  0.04779297 -0.7685739
#   0.99387026]
# Collision Detected!Acceleration: Vector3D(x=0.219942, y=0.404544, z=9.794486)
# Gyroscope: Vector3D(x=0.004358, y=0.000392, z=0.032053)
# Compass: 0.21863491833209991
#
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-3.0027635  -0.43423828  0.53497434 ...  0.04776367 -0.76844174
#   0.99387133]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.262848, y=0.447331, z=9.811406)
# Gyroscope: Vector3D(x=-0.004600, y=0.001020, z=0.002696)
# Compass: 0.21888814866542816
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.975537   -0.5399609   0.53324    ...  0.09574219 -0.77038753
#   0.99385583]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.218368, y=0.184694, z=9.796066)
# Gyroscope: Vector3D(x=-0.002553, y=0.000123, z=-0.001477)
# Compass: 0.21847189962863922
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-0.19278319  7.157334    1.2624856  ...  0.04777344 -0.7684738
#   0.9938711 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.240555, y=0.364799, z=9.799780)
# Gyroscope: Vector3D(x=-0.003264, y=0.001076, z=-0.000005)
# Compass: 0.21799618005752563
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.975996   -0.5400683   0.5333084  ...  0.14376953 -0.77204466
#   0.9938427 ]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Acceleration: Vector3D(x=0.236408, y=0.398169, z=9.805504)
# Gyroscope: Vector3D(x=0.001139, y=0.000174, z=-0.006685)
# Compass: 0.2176334708929062
# Collision Detected!
# Collision Detected!
# Collision Detected!
# LiDAR Data: [-2.9741113  -0.53973633  0.4630725  ...  0.19186524 -0.7739657
#   0.99382734]
# Collision Detected!
# Collision Detected!
# Collision Detected!
# Destroying actors
# Acceleration: Vector3D(x=0.229906, y=0.487218, z=9.799954)
# Gyroscope: Vector3D(x=-0.001013, y=0.000429, z=-0.005861)
# Compass: 0.2177560031414032
# LiDAR Data: [ 0.06459961  7.19707     1.2690909  ...  0.04777344 -0.7684747
#   0.9938711 ]
# Done.

# %% [markdown]
# 2. DDPG Implementation

# %%
import glob
import os
import sys
import carla
import random
import time
import numpy as np
import cv2
import math

SHOW_CAM = False
IM_WIDTH = 640
IM_HEIGHT = 480
SECONDS_PER_EPISODE = 10

class CarEnv:
    # Define constants that are required
    STEER_AMT = 1.0
    im_width = IM_WIDTH
    im_height = IM_HEIGHT
    front_camera = None

    def __init__(self):
        self.client = carla.Client("localhost", 2000)
        self.client.set_timeout(10)
        self.world = self.client.get_world()
        self.blueprint_library = self.world.get_blueprint_library()
        self.model_3 = self.blueprint_library.filter("model3")[0]

        self.collision_hist = []
        self.actor_list = []

        self.front_camera = None
        self.episode_start = 0

    def reset(self):
        self.collision_hist = []
        self.actor_list = []

        self.transform = random.choice(self.world.get_map().get_spawn_points())
        self.vehicle = self.world.spawn_actor(self.model_3, self.transform)
        self.actor_list.append(self.vehicle)

        self.rgb_cam = self.blueprint_library.find('sensor.camera.rgb')
        self.rgb_cam.set_attribute("image_size_x", f"{self.im_width}")
        self.rgb_cam.set_attribute("image_size_y", f"{self.im_height}")
        self.rgb_cam.set_attribute("fov", f"110")
        transform = carla.Transform(carla.Location(x=2.5, z=0.7))
        self.sensor = self.world.spawn_actor(self.rgb_cam, transform, attach_to=self.vehicle)
        self.actor_list.append(self.sensor)

        self.lidar_sensor = self.blueprint_library.find('sensor.lidar.ray_cast')
        transform = carla.Transform(carla.Location(x=2.0, z=0.9))
        self.sensor = self.world.spawn_actor(self.lidar_sensor, transform, attach_to=self.vehicle)
        self.actor_list.append(self.sensor)

        self.imu_sensor = self.blueprint_library.find('sensor.other.imu')
        transform = carla.Transform(carla.Location(x=2.0, y=1.0, z=0.8))
        self.sensor = self.world.spawn_actor(self.imu_sensor, transform, attach_to=self.vehicle)

        self.gps_sensor = self.blueprint_library.find('sensor.other.gnss')
        transform = carla.Transform(carla.Location(x=1.5, z=0.7))
        self.sensor = self.world.spawn_actor(self.gps_sensor, transform, attach_to=self.vehicle)

        self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))
        time.sleep(4)

        colsensor = self.blueprint_library.find("sensor.other.collision")
        self.colsensor = self.world.spawn_actor(colsensor, transform, attach_to=self.vehicle)
        self.actor_list.append(self.colsensor)
        self.colsensor.listen(lambda event: self.collision_data(event))

        while self.front_camera is None:
            time.sleep(0.01)

        self.episode_start = time.time()
        self.vehicle.apply_control(carla.VehicleControl(throttle=0.0, brake=0.0))

        return self.front_camera

    def collision_data(self, event):
        self.collision_hist.append(event)

    def process_img(self, image):
        i = np.array(image.raw_data)
        i2 = i.reshape((self.im_height, self.im_width, 4))
        i3 = i2[:, :, :3]
        if SHOW_CAM:
            cv2.imshow("", i3)
            cv2.waitKey(1)
        self.front_camera = i3

    def step(self, action):
        if action == 0:
            self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, steer=-self.STEER_AMT))
        elif action == 1:
            self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, steer=0))
        elif action == 2:
            self.vehicle.apply_control(carla.VehicleControl(throttle=1.0, steer=self.STEER_AMT))

        v = self.vehicle.get_velocity()
        kmh = int(3.6 * math.sqrt(v.x**2 + v.y**2 + v.z**2))

        if len(self.collision_hist) != 0:
            done = True
            reward = -200
        elif kmh < 50:
            done = False
            reward = -1
        else:
            done = False
            reward = 1

        if self.episode_start + SECONDS_PER_EPISODE < time.time():
            done = True

        return self.front_camera, reward, done, None

# %%
# Define the Actor neural network

# import necessary libraries -------------------check which are already downlaoded using pip list command

# import pandas as pd      ------------------------Download using
# import numpy as np       -----------------------pip install numpy     
# import matplotlib.pyplot as plt                 pip install matplotlib
# import seaborn as sns ------------------------ !pip install seaborn
# import tensorflow as tf     ------------------ !pip install tensorflow
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.optimizers import Adam



class ActorNetwork(tf.keras.Model): # inherting tf.keras.Model so that we don't have to write it again and again
    def __init__(self, n_actions): # n_actioins are the number of possible actions
        super(ActorNetwork, self).__init__() # calling the costructor of parent class
        self.dense1 = Dense(64, activation='relu')
        self.dense2 = Dense(64, activation='relu')
        self.output_layer = Dense(n_actions, activation='softmax') # OUTPUT  neurons are equal to number of actions that has to be taken like if 2 then 1 for throttle and 1 for steering

    # call function is used to call the actor and pass it the state representation to return the output
    def call(self, state): 
        x = self.dense1(state)
        x = self.dense2(x)
        return self.output_layer(x)

# Define the Critic neural network
class CriticNetwork(tf.keras.Model):
    def __init__(self):
        super(CriticNetwork, self).__init__()
        self.dense1 = Dense(64, activation='relu')
        self.dense2 = Dense(64, activation='relu')
        self.output_layer = Dense(1)

    # call the critic to evaluate the performance of actor network
    def call(self, state):
        x = self.dense1(state)
        x = self.dense2(x)
        return self.output_layer(x)

# Define the DRL Actor-Critic agent
class DRLActorCritic:
    def __init__(self, state_dim, n_actions, lr_actor=0.001, lr_critic=0.001):
        self.state_dim = state_dim
        self.n_actions = n_actions  

        self.actor = ActorNetwork(n_actions)
        self.critic = CriticNetwork()

        self.actor_optimizer = Adam(learning_rate=lr_actor)
        self.critic_optimizer = Adam(learning_rate=lr_critic)

    def get_action(self, state): # it will take state generated by reset function, pass it to the actor network 
        #and returns an action Get action probabilities from the actor network
        
        action_probs = self.actor(np.array([state]))
        action = np.random.choice(self.n_actions, p=action_probs.numpy()[0])
        return action, action_probs

    def train(self, states, actions, discounted_rewards): 
        '''
          It will take state generated by the reset function, action predicted by the actor network and its cummulative reward
          
         it should take state and action taken by actor and use them to calculate max cummulative reward and use temporal
         difference to update the weights of actor and its own network
        
        it is for training of both the neural networks and does not return any value as such
        '''
        with tf.GradientTape() as actor_tape, tf.GradientTape() as critic_tape:
            # Convert inputs to TensorFlow tensors
            states = tf.convert_to_tensor(states, dtype=tf.float32)
            actions = tf.convert_to_tensor(actions, dtype=tf.int32)
            discounted_rewards = tf.convert_to_tensor(discounted_rewards, dtype=tf.float32)

            # Get action probabilities from the actor
            action_probs = self.actor(states)

            # Use actions to index into action_probs and calculate log probabilities
            selected_action_probs = tf.gather(action_probs, actions, batch_dims=1)
            log_action_probs = tf.math.log(selected_action_probs)

            # Calculate actor loss (policy gradient)
            actor_loss = -tf.reduce_sum(log_action_probs * discounted_rewards)

            # Calculate critic loss (mean squared error)
            state_values = self.critic(states)
            critic_loss = tf.reduce_mean(tf.square(discounted_rewards - state_values))

        # Compute gradients
        actor_gradients = actor_tape.gradient(actor_loss, self.actor.trainable_variables)
        critic_gradients = critic_tape.gradient(critic_loss, self.critic.trainable_variables)

        # Apply gradients to update actor and critic
        self.actor_optimizer.apply_gradients(zip(actor_gradients, self.actor.trainable_variables))
        self.critic_optimizer.apply_gradients(zip(critic_gradients, self.critic.trainable_variables)

        # Return the actor and critic loss for monitoring
        return actor_loss, critic_loss

# %%
if __name__ == '__main__':
    vehicle = CarEnv()
    initial_state = vehicle.reset()
    n_actions = 2
    state_dim = initial_state.shape[0]  # Use shape[0] to get the number of features in the state
    agent = DRLActorCritic(state_dim, n_actions)

    max_steps = 100  # You should define the value of 'max_steps' somewhere

    # Perform multiple steps within the episode
    for t in range(max_steps):
        action, action_probs = agent.get_action(initial_state)  # The agent selects an action
        next_state, reward, done, info = vehicle.step(action)  # Perform a step in the environment
        

        if done:
            break  # The episode is done, and you can reset the environment for the next episode if needed
        else:
            initial_state = next_state  # Update the state for the next step

# %% [markdown]
# 1. Check step function
# 2. make proper reward function
# 3. deal with state representation of the environment (camera data)
# 4. deal with synchronouse mode in reset function
